# %%
from llama_index.llms.openai import OpenAI # 라마인덱스 OpenAI LLM 모델을 불러오기 위함 
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader # 문서 로드 및 Index
import os # 환경변수 사용
from dotenv import load_dotenv # 환경변수 로드

# %%
# .env 파일 로드
load_dotenv()

# OpenAI API 키 설정
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
# OpenAI GPT-4o 모델을 사용하도록 설정
llm = OpenAI(model="gpt-4o")

# %%
documents = SimpleDirectoryReader(input_dir="../data/pdf_sample1").load_data()

# %%
print(documents[2])
# Out:
# Doc ID: bf1fe629-1d47-40c5-907e-64702f0fcf11
# Text: NIA AI정책본부 미래전략팀 이정아(leeja@nia.or.kr)  THE AI REPORT  2024-3 |
# 2024.9.11. 1 미국의 인공지능(AI) 정책 전략 현황과 변화 방향 -AI 지배력 강화와 초강대국 유지를 위해 미국은
# 어떻게 변화하고 있는가? - 1. 미국의 인공지능(AI) 정책 기조와 주요 변화   미 행정부의 변화 : AI 경쟁력
# 확보․강화에서 ‘AI 팍스 아메리카나’로  ○ 미국 역대 정권의 AI 정책 기조는, 시장과 기술 우위성을 토대로 막대한
# 연구개발(R&D) 투자를 확대해 AI 강국의 지위를 더욱 공고히 하고, 세계 최고의 AI 경쟁력을 유지하는 것 - 오바마
# 행정부는 AI R&D 전...

# %%
index = VectorStoreIndex.from_documents(documents, llm=llm)
# Out:
# 2026-01-08 10:22:55,816 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 index = VectorStoreIndex.from_documents(documents, llm=llm)
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/core/indices/base.py:122, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, **kwargs)
#     113     docstore.set_document_hash(doc.id_, doc.hash)
#     115 nodes = run_transformations(
#     116     documents,  # type: ignore
#     117     transformations,
#     118     show_progress=show_progress,
#     119     **kwargs,
#     120 )
# --> 122 return cls(
#     123     nodes=nodes,
#     124     storage_context=storage_context,
#     125     callback_manager=callback_manager,
#     126     show_progress=show_progress,
#     127     transformations=transformations,
#     128     **kwargs,
#     129 )
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/core/indices/vector_store/base.py:75, in VectorStoreIndex.__init__(self, nodes, use_async, store_nodes_override, embed_model, insert_batch_size, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      70 self._embed_model = resolve_embed_model(
#      71     embed_model or Settings.embed_model, callback_manager=callback_manager
#      72 )
#      74 self._insert_batch_size = insert_batch_size
# ---> 75 super().__init__(
#      76     nodes=nodes,
#      77     index_struct=index_struct,
#      78     storage_context=storage_context,
#      79     show_progress=show_progress,
#      80     objects=objects,
#      81     callback_manager=callback_manager,
#      82     transformations=transformations,
#      83     **kwargs,
#      84 )
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/core/indices/base.py:79, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      77 if index_struct is None:
#      78     nodes = nodes or []
# ---> 79     index_struct = self.build_index_from_nodes(
#      80         nodes + objects,  # type: ignore
#      81         **kwargs,  # type: ignore
#      82     )
#      83 self._index_struct = index_struct
#      84 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/core/indices/vector_store/base.py:309, in VectorStoreIndex.build_index_from_nodes(self, nodes, **insert_kwargs)
#     306 if len(content_nodes) != len(nodes):
#     307     print("Some nodes are missing content, skipping them...")
# --> 309 return self._build_index_from_nodes(content_nodes, **insert_kwargs)
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/core/indices/vector_store/base.py:278, in VectorStoreIndex._build_index_from_nodes(self, nodes, **insert_kwargs)
#     276     run_async_tasks(tasks)
#     277 else:
# --> 278     self._add_nodes_to_index(
#     279         index_struct,
#     280         nodes,
#     281         show_progress=self._show_progress,
#     282         **insert_kwargs,
#     283     )
#     284 return index_struct
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/core/indices/vector_store/base.py:231, in VectorStoreIndex._add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     228     return
#     230 for nodes_batch in iter_batch(nodes, self._insert_batch_size):
# --> 231     nodes_batch = self._get_node_with_embedding(nodes_batch, show_progress)
#     232     new_ids = self._vector_store.add(nodes_batch, **insert_kwargs)
#     234     if not self._vector_store.stores_text or self._store_nodes_override:
#     235         # NOTE: if the vector store doesn't store text,
#     236         # we need to add the nodes to the index struct and document store
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/core/indices/vector_store/base.py:138, in VectorStoreIndex._get_node_with_embedding(self, nodes, show_progress)
#     126 def _get_node_with_embedding(
#     127     self,
#     128     nodes: Sequence[BaseNode],
#     129     show_progress: bool = False,
#     130 ) -> List[BaseNode]:
#     131     """
#     132     Get tuples of id, node, and embedding.
#     133
#    (...)
#     136
#     137     """
# --> 138     id_to_embed_map = embed_nodes(
#     139         nodes, self._embed_model, show_progress=show_progress
#     140     )
#     142     results = []
#     143     for node in nodes:
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/core/indices/utils.py:176, in embed_nodes(nodes, embed_model, show_progress)
#     173     else:
#     174         id_to_embed_map[node.node_id] = node.embedding
# --> 176 new_embeddings = embed_model.get_text_embedding_batch(
#     177     texts_to_embed, show_progress=show_progress
#     178 )
#     180 for new_id, text_embedding in zip(ids_to_embed, new_embeddings):
#     181     id_to_embed_map[new_id] = text_embedding
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/core/base/embeddings/base.py:473, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     468 with self.callback_manager.event(
#     469     CBEventType.EMBEDDING,
#     470     payload={EventPayload.SERIALIZED: self.to_dict()},
#     471 ) as event:
#     472     if not self.embeddings_cache:
# --> 473         embeddings = self._get_text_embeddings(cur_batch)
#     474     elif self.embeddings_cache is not None:
#     475         embeddings = self._get_text_embeddings_cached(cur_batch)
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/embeddings/openai/base.py:472, in OpenAIEmbedding._get_text_embeddings(self, texts)
#     463 @retry_decorator
#     464 def _retryable_get_embeddings():
#     465     return get_embeddings(
#     466         client,
#     467         texts,
#     468         engine=self._text_engine,
#     469         **self.additional_kwargs,
#     470     )
# --> 472 return _retryable_get_embeddings()
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/tenacity/__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/tenacity/__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File ~/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/embeddings/openai/base.py:465, in OpenAIEmbedding._get_text_embeddings.<locals>._retryable_get_embeddings()
#     463 @retry_decorator
#     464 def _retryable_get_embeddings():
# --> 465     return get_embeddings(
#     466         client,
#     467         texts,
#     468         engine=self._text_engine,
#     469         **self.additional_kwargs,
#     470     )
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/llama_index/embeddings/openai/base.py:172, in get_embeddings(client, list_of_text, engine, **kwargs)
#     168 assert len(list_of_text) <= 2048, "The batch size should not be larger than 2048."
#     170 list_of_text = [text.replace("\n", " ") for text in list_of_text]
# --> 172 data = client.embeddings.create(input=list_of_text, model=engine, **kwargs).data
#     173 return [d.embedding for d in data]
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/openai/resources/embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/workspace/study/LlamaIndex_Code/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-****************************************************************************************************************************************************************************************************************************************************************************************************************************sDwA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("미국의 인공지능 정책과 주요 변화에 대해 알려주세요")

# %%
print(response)

# %%
print(response.metadata)
